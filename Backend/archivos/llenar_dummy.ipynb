# %% [markdown]
# # Llenado de Tablas Dummy en MySQL
#
# Este notebook inserta datos coherentes de ejemplo en tu base de datos MySQL conectada vía Railway.
#
# **Pasos**:
# 1. Asegúrate de tener acceso a la URL de conexión.
# 2. Ejecuta la celda de instalación de dependencias.
# 3. Ejecuta la celda de inserción de datos.

# %%
# 1) Instalar dependencias (ejecutar solo la primera vez)
# !pip install SQLAlchemy PyMySQL Faker

# 2) Importar librerías y configurar conexión
from sqlalchemy import create_engine, text
from faker import Faker
import random
from datetime import datetime, timedelta

# Reemplaza esta URL con tu cadena de conexión completa
DATABASE_URL = "mysql+pymysql://root:FmakntvOnXOIsLWTzbomCOGwsSoEbPhS@tramway.proxy.rlwy.net:58325/railway"

engine = create_engine(DATABASE_URL, echo=True)
fake = Faker("es_CO")

# 3) Abrir transacción y desactivar verificaciones de FK
with engine.begin() as conn:
    conn.execute(text("SET FOREIGN_KEY_CHECKS = 0"))

    # --- Tipo de documento ---
    tipos = [(1, "Cédula de Ciudadanía"), (2, "NIT"), (3, "Cédula de Extranjería")]
    for id_, nombre in tipos:
        conn.execute(
            text(
                "INSERT INTO tipo_documento (id, nombre) "
                "VALUES (:id, :nombre) "
                "ON DUPLICATE KEY UPDATE nombre = VALUES(nombre)"
            ),
            {"id": id_, "nombre": nombre},
        )

    # --- Municipio ---
    municipios = [
        (1, "La Ceja", "Antioquia"),
        (2, "Tuluá", "Valle del Cauca"),
        (3, "Pitalito", "Huila"),
    ]
    for id_, nombre, depto in municipios:
        conn.execute(
            text(
                "INSERT INTO municipio (id, nombre, departamento) "
                "VALUES (:id, :nombre, :depto) "
                "ON DUPLICATE KEY UPDATE "
                "nombre = VALUES(nombre), departamento = VALUES(departamento)"
            ),
            {"id": id_, "nombre": nombre, "depto": depto},
        )

    # --- Categoría de insumo ---
    categorias = [(1, "Fertilizante"), (2, "Fungicida"), (3, "Insecticida")]
    for id_, nombre in categorias:
        conn.execute(
            text(
                "INSERT INTO categoria_insumo (id, nombre) "
                "VALUES (:id, :nombre) "
                "ON DUPLICATE KEY UPDATE nombre = VALUES(nombre)"
            ),
            {"id": id_, "nombre": nombre},
        )

    # Agrega aquí más bloques para las demás tablas siguiendo el mismo patrón...
    # Usuario, Predio, Calidad, Producto, Cosecha, Cosecha_Predio, Insumo, Insumo_Cosecha,
    # Comprador, Exportación, Exportacion_Cosecha

    # Reactivar verificaciones de FK
    conn.execute(text("SET FOREIGN_KEY_CHECKS = 1"))

print("¡Datos dummy insertados correctamente!")
# Out:
# ...
# 2025-06-07 00:36:55,708 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2025-06-07 00:36:55,709 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-07 00:36:55,852 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2025-06-07 00:36:55,853 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-07 00:36:55,925 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2025-06-07 00:36:55,926 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-06-07 00:36:56,147 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-06-07 00:36:56,148 INFO sqlalchemy.engine.Engine SET FOREIGN_KEY_CHECKS = 0
# 2025-06-07 00:36:56,149 INFO sqlalchemy.engine.Engine [generated in 0.00072s] {}
# 2025-06-07 00:36:56,235 INFO sqlalchemy.engine.Engine INSERT INTO tipo_documento (id, nombre) VALUES (%(id)s, %(nombre)s) ON DUPLICATE KEY UPDATE nombre = VALUES(nombre)
# 2025-06-07 00:36:56,235 INFO sqlalchemy.engine.Engine [generated in 0.00079s] {'id': 1, 'nombre': 'Cédula de Ciudadanía'}
# ...
